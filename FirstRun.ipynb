# %%
import os
import pandas as pd
import sys
import logging

## modules
sys.path.insert(0, './_modules')
from path_definitions import control_dir, att_dir
from orchestra_module import mailId_query, get_table, TheGreatFilter, TheCollector, Orchestrator
from logging_module import getlogger
import random
import numpy as np
import time
import schedule
# Out:
# /home/dev/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Credentials ok!

# %%
logging = getlogger()

# %%
#logging.info('Test')

# %%
control_path = control_dir()
# Out:
# Folder already exists.
# /home/dev/sigo/_collect_control

# %%
att_path = att_dir()
# Out:
# Folder already exists.
# /home/dev/sigo/_attachments

# %%
all_mid_list = mailId_query(control_path, new_query = False, query_type = 'full')
# Out:
# All mails counting: 12981

# %%
splitted_mail_list, mail_counter = TheGreatFilter(all_mid_list, control_path)
# Out:
# 11490

# %%
len(splitted_mail_list)
# Out:
# 100

# %%
splitted_mail_list[0]
# Out:
# array(['16e1ea9cc0872efc', '16fb436147e0bac8', '16c7715fefc0570b',
#        '16eacad4a5cc38d5', '16e4d3b5937028d8', '16d02bd026d5cec5',
#        '16dedeaf207f32dc', '16c439e97a09273f', '16f1099d87ec86ac',
#        '16e054e062a32a39', '16e38a48c85c36c2', '16dbc7663c0504a4',
#        '16db63ce84e1066f', '16d6f338ffe3ee16', '16f2418a6f3dfe22',
#        '16f162dc600d1685', '16d6017478f0efa9', '16f15807896a2bd2',
#        '16c883a9430da3b6', '17010f223503d5ac', '16c301d1594951de',
#        '16c8d9d36583fd15', '16d8dc7ba94614d0', '17010a4a0bbf9606',
#        '16f1fc18a89520e6', '1705eec9dfacfbfd', '16dcb4f679dd7715',
#        '16dd0c6eec84f82c', '16de1110e123e285', '16d6f40e405eb3a2',
#        '170638a8476fe55c', '16f8cc92a3776624', '16d700043f9dd058',
#        '16c1b5fa44a1bc22', '16dcbb37c1b4e79d', '170635e193ab214a',
#        '16f1aeb07b28de60', '16ccf5aa1525befb', '16ef72652eea6bde',
#        '16d3fe7a1a3e3ab3', '16eae1b86638e6c0', '16c4da0bcab574e6',
# ...

# %%
for subset_mail_list in splitted_mail_list:
    print(len(subset_mail_list))
# Out:
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114

# %%
## tests
#splitted_mail_list = splitted_mail_list[0:3]
#print(len(splitted_mail_list))
## working perfectely
#results_collector = TheCollector(splitted_mail_list, control_path, att_path)

# %%
results = Orchestrator(control_path, att_path, new_query = False, query_type = 'full')
# Out:
# All mails counting: 12981
# 11847
# 16eece5e89849187
# From: Fabio Moreira <advogadofabiomoreira@gmail.com>
# Date: Mon, 9 Dec 2019 20:01:59 -0300
# Subject: Re: Diligência - Departamento de Combate ao Roubo às Instituições Financeiras de São Luís/MA
#
#
# 16cda7706db65130
# From: Helena Rossi <helena.rossi@carinaquito.com>
# Subject: [8-3840000027303] - c 2019/09/02 - September 02nd, 2019 - CRIMINAL - GMAIL - CRIMINAL ASSOCIATION - TRIX #6619 - 2nd Request
# Date: Wed, 28 Aug 2019 20:01:45 -0300
#
#
# 17054cd3d7e8d8b1
# Date: Mon, 17 Feb 2020 20:18:21 +0000
# Subject: Re: [6-3978000029682] - LEGAL ISSUE- URGENT - 2 HOURS - OVERDUE - c 2020/02/12 - February 12th, 2020 - CRIMINAL - GMAIL - MURDER - CRIMINAL ORGANIZATION - TRIX #8089 - 2nd Request
# From: lis-latam@google.com
#
#
# 16ec753038befa8e
# Date: Mon, 02 Dec 2019 15:55:35 +0000
# Subject: FWD: [3-9483000028573] BR Data Request 0183.19.007900-8
# From: lis-latam@google.com
#
#
# 16d4148c6f52cf0d
# ...

# %%
df_test = get_table('screening_table', option = 'full')

# %%
df_test
# Out:
#       main_id           mail_id         thread_id mail_date_received  \
# 0           1  16e621b40e2a0718  16e3d0dba31c9f02         2019-11-13
# 1           2  16d5f62086593562  16d2ce551f3bb65a         2019-09-23
# 2           3  16c0626420c86643  16bfb3ebc5852120         2019-07-18
# 3           4  16eb93bc25e0f323  16eb93bc25e0f323         2019-11-29
# 4           5  1700ca8ed5948627  16fe9671f13a5e14         2020-02-03
# ...       ...               ...               ...                ...
# 8731     8732  16c72921c0ee0b71  16c72921c0ee0b71         2019-08-08
# 8732     8733  16cfed1ff691e73b  16caf4b9c50f4f9e         2019-09-05
# 8733     8734  16d8cfba4a550125  16d8cfba4a550125         2019-10-02
# 8734     8735  16c6d8df3c46bf5c  16c6d8df3c46bf5c         2019-08-07
# 8735     8736  16ffd9074f92e4e4  16ffd9074f92e4e4         2020-01-31
#
#      mail_hms_received                                       mail_subject  \
# ...

# %%
df_test.drop_duplicates('mail_id')
# Out:
#       main_id           mail_id         thread_id mail_date_received  \
# 0           1  16e621b40e2a0718  16e3d0dba31c9f02         2019-11-13
# 1           2  16d5f62086593562  16d2ce551f3bb65a         2019-09-23
# 2           3  16c0626420c86643  16bfb3ebc5852120         2019-07-18
# 3           4  16eb93bc25e0f323  16eb93bc25e0f323         2019-11-29
# 4           5  1700ca8ed5948627  16fe9671f13a5e14         2020-02-03
# ...       ...               ...               ...                ...
# 1486     1487  16eea821deac43ef  16eea821deac43ef         2019-12-09
# 1487     1488  16ec89dd3929783d  16ec89dd3929783d         2019-12-02
# 1488     1489  16e03f97e307d246  16e03f97e307d246         2019-10-25
# 1489     1490  17016f56704861b1  17016f56704861b1         2020-02-05
# 1490     1491  16dd1ba78d807182  16dd1ba78d807182         2019-10-15
#
#      mail_hms_received                                       mail_subject  \
# ...
