# %%
import os
import pandas as pd
import sys
import numpy as np
import time
import schedule
from datetime import datetime

sys.path.insert(0, './_modules')
from db_functions import TheDB
from general_functions import clean_text
#from logging_module import getlogger
#from logging_module_v2 import StartLogger
# Out:
# /home/dev/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /home/dev/sigo_prod_v2

# %%
## bots BD connections
conn_dict = {'host':'localhost', 'database': 'brspcqadev',
             'user':'root', 'password':'quito2020'}

cqdb_prod = TheDB(conn_dict)

# %%
df = cqdb_prod.GetTable('Screening')
df = df.loc[:, ['mail_id', 'mail_from', 'mail_body']]
df
# Out:
#                 mail_id             mail_from  \
# 0      16e621b40e2a0718  lis-latam@google.com
# 1      16d5f62086593562  lis-latam@google.com
# 2      16c0626420c86643   tatesser@google.com
# 3      16eb93bc25e0f323  lis-latam@google.com
# 4      1700ca8ed5948627  lis-latam@google.com
# ...                 ...                   ...
# 42906  1791fbfc16ec319e  lis-latam@google.com
# 42907  1791fc429c9e5d47  lis-latam@google.com
# 42908  1791fdb5e93fda1c  lis-latam@google.com
# 42909  1791feea83c06f59  lis-latam@google.com
# 42910  179208bc4b000b3a  lis-latam@google.com
#
#                                                mail_body
# 0                                                 b'...'
# 1                                                 b'...'
# 2                                                 b'...'
# 3                                                 b'...'
# 4                                                 b'...'
# ...                                                  ...
# 42906  b'Urgent: 48 hr deadine\r\n\r\nHi team,\r\n\r\...
# 42907  b'\r\n\r\nHi all,\r\n\r\nAttached the response...
# 42908  b'\r\n\r\nHi all,\r\n\r\nAttached the response...
# 42909  b'\r\n\r\n*FYI - LLC non-BR Target*\r\n\r\nHi ...
# 42910  b'\r\n\r\nHi team,\r\n\r\nPlease see below the...
#
# [42911 rows x 3 columns]

# %%
def SplitMail(text, clean = False):
    text = text.decode('utf-8')
    text = text.split('*De:*')[0]
    
    if clean == True:
        text = clean_text(text)
    
    return text

# %%
text = df['mail_body'][4293]
text = SplitMail(text, clean = False)
print(text)
# Out:
# Hi all,
#
# Attached the response letter for this case. Production was shared directly
# with LE via LERS toVictor Bruno da Silva Menezes, Delegado de Polícia
# (Polícia Civil do Estado do Paraná)
# del.vbsmenezes@pc.pr.gov.br
# (M) +55 (41) 99192-7390
#
# Best,
#
# Gilda - LIS
#
#
# On Thu, Oct 10, 2019 at 22:12 UTC "Helena Rossi" <
# helena.rossi@carinaquito.com> wrote:
#
# *Last Name: *Vara Privativa do 1º Tribunal do Júri do Foro Central da
# Comarca da Região Metropolitana de Curitiba/PR
#
#
#
# *Country: *BR
#
#
#
# *External Reference Number: *0001305-19.2019.8.16.0006
#
#
#
# *Date the Court Order was Issued: *2019/10/04
#
#
#
# *Date Received: *2019/10/09
#
#
#
# *Due Date: *2019/10/10
#
#
#
# *Targets:* 353xxx470, 353xxx477, 352xx659, 352xxx657
#
#
#
# *Info: *Ofício nº 2925/2019
#
#
#
# *Trix* #7083
#
#
#
# *Related to:* [2-8305000028404]
#
#
#
# *LP indicates email for delivery of response: *
#
#
#
# Yes (share data directly with LE):
#
# Via LERS
#
#
#
# *Counsel needs to review letter: no*
#
#
#
# LEGAL OPINION:
#
# 1/ Background: n/a
#
#
#
# 2/ Legal risk: Contempt charges
#
#
#
# 3/ Legal issue: n/a
#
#
#
# 4/ Additional information:
#
#
#
#     - There is a request for YT.
#
#
#
#     - NOI was confirmed by calling LE.
#
#
#
#     - Please notice that we received the CO three times yesterday, under the
#     same thread number.
#
#
#
# Letter should be addressed to: Exmo. Senhor Delegado de Polícia Civil do
# Estado do Paraná - Dr. Victor Bruno da Silva Menezes
#
#
#
# *Silo*: International Criminal
