# %%
import os
import pandas as pd
import sys
import numpy as np
import time
import schedule
from datetime import datetime

sys.path.insert(0, './_modules')
from db_functions import TheDB
from general_functions import clean_text
#from logging_module import getlogger
#from logging_module_v2 import StartLogger
# Out:
# /home/dev/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /home/dev/sigo_prod_v2

# %%
## bots BD connections
conn_dict = {'host':'localhost', 'database': 'brspcqadev',
             'user':'root', 'password':'quito2020'}

cqdb_prod = TheDB(conn_dict)

# %%
df = cqdb_prod.GetTable('Screening')

# %%
df = df.loc[:, ['mail_id', 'mail_from', 'mail_body']]
df
# Out:
#                 mail_id             mail_from  \
# 0      16e621b40e2a0718  lis-latam@google.com
# 1      16d5f62086593562  lis-latam@google.com
# 2      16c0626420c86643   tatesser@google.com
# 3      16eb93bc25e0f323  lis-latam@google.com
# 4      1700ca8ed5948627  lis-latam@google.com
# ...                 ...                   ...
# 42906  1791fbfc16ec319e  lis-latam@google.com
# 42907  1791fc429c9e5d47  lis-latam@google.com
# 42908  1791fdb5e93fda1c  lis-latam@google.com
# 42909  1791feea83c06f59  lis-latam@google.com
# 42910  179208bc4b000b3a  lis-latam@google.com
#
#                                                mail_body
# 0                                                 b'...'
# 1                                                 b'...'
# 2                                                 b'...'
# 3                                                 b'...'
# 4                                                 b'...'
# ...                                                  ...
# ...

# %%
text = df['mail_body'][42909]
print(text.decode('utf-8'))
# Out:
# *FYI - LLC non-BR Target*
#
# Hi all,
#
# Attached the response letter/planilha for this case. Production was shared
# directly with LE via LERS to cloves.nascimento@pc.es.gov.br.
#
# Best,
#
# Ari - LIS
#
# On Tue, Apr 27, 2021 at 15:43 UTC "Artur Rovere" <
# artur.rovere@carinaquito.com> wrote:
#
# Hi LIS,
#
#
#
# This is related to [4-1970000031618] - c 2021/03/25 - March 25th, 2021 -
# CRIMINAL - GMAIL - EXTORTION - TRIX #12951
#
#
#
# LE resent the CO with the pages that were missing before. Considering you
# already informed us the only target is a FIP account we advise LIS to share
# a response letter addressing the issue directly with LE. You may send it
# via e-mail to drcc.cartorio@pc.es.gov.br.
#
#
#
# Letter should be addressed to: Exmo. Senhor Delegado de Polícia da DRCC em
# Vitória/ES - Dr. Brenno Andrade de Souza Silva.
#
#
#
# Best,
#
#
#
# *De:* lis-latam@google.com <lis-latam@google.com>
# *Enviada em:* quinta-feira, 22 de abril de 2021 12:45
# ...

# %%
df_trix = cqdb_prod.GetTable('Trix_Oficial')

# %%
df_trix
# Out:
#        line_id          case_id        external_ref_number   deadline  \
# 0            1                    0009460-19.2013.403.6181 1946-02-12
# 1            2  6-9080000028545   0002618-91.2011.403.6181 1946-02-12
# 2            3  9-5821000001559   0007067-24.2013.403.6181 1946-02-12
# 3            4  5-6191000002205                            1946-02-12
# 4            5  9-9709000000828   0076690-72.2011.805.0001 1946-02-12
# ...        ...              ...                        ...        ...
# 10546    10547    missing_value              missing_value 1946-02-12
# 10547    10548  4-9100000031065  1042340-66.2019.8.13.0024 1946-02-12
# 10548    10549  3-5849000026727   014055-55.2019.8.06.0001 1946-02-12
# 10549    10550    missing_value              missing_value 1946-02-12
# 10550    10551  5-2935000030843      5314-98.2020.811.0015 1946-02-12
#
#       date_received date_received_cq auth_last_name info_case case_country  \
# ...

# %%
cqdb_prod.TablesDataType('Trix')
# Out:
#                                   0            1    2    3     4 5
# 0                           line_id      int(11)   NO  PRI  None
# 1                           case_id     longtext  YES       None
# 2               external_ref_number     longtext  YES       None
# 3                          deadline  datetime(6)   NO       None
# 4                     date_received  datetime(6)   NO       None
# 5                  date_received_cq  datetime(6)   NO       None
# 6                    auth_last_name     longtext  YES       None
# 7                         info_case     longtext  YES       None
# 8                      case_country     longtext  YES       None
# 9                    email_response     longtext  YES       None
# 10                           status     longtext  YES       None
# 11                          targets     longtext  YES       None
# 12                             lers     longtext  YES       None
# ...

# %%
set(df_trix.columns)
# Out:
# {'case_id',
#  'date_created',
#  'date_modified',
#  'date_received',
#  'date_received_cq',
#  'date_status_ms',
#  'deadline',
#  'deadline_ms',
#  'external_ref_number',
#  'line_id',
#  'users_id'}

# %%
df_screening = cqdb_prod.GetTable('Screening')

# %%
print(df_screening.sort_values('date_created', ascending = False).reset_index()['mail_body'][2].decode('utf-8'))
# Out:
# *Last Name*: 7ª Vara Criminal da Comarca de Salvador/BA
#
# *Country: *BR
#
# *External Reference Number*: 0307080-26.2020.8.05.0001
#
# *Date the Court Order was Issued: *2020/10/23
#
# *Date Received: *2020/10/23
#
# *Due Date: *2020/10/30
#
# *Targets*: isaxxx -- Gmail, conxxx -- Gmail
#
# *Info: *n/a
#
# *Trix *#11341
#
# *Related to:* [7-6637000030954]
#
#
#
# *LP indicates email for delivery of response:*
#
#
#
# Yes (share data directly with LE):
#
# Via LERS
#
#
#
# *Counsel needs to review letter: no*
#
#
#
# LEGAL OPINION:
#
#
#
# 1/ Background: this is related to registration data authority request
# processed on “RES: [6-2781000030725] 2020/09/11 - Criminal - Authority -
# Gmail - Case 2398937 - Outside Counsel - READ”
#
#
#
# 2/ Legal risks: n/a
#
#
#
# 3/ Legal issue: NOI is punished with “detenção”. Thus, please solely
# provide reg data and logs for the targeted accounts.
#
#
#
# 4/ Petition: Yes - CQ will file a petition after LIS responds to the CO.
#
#
#
# ...

# %%
df_screening
# Out:
#        main_id           mail_id         thread_id  mail_date_received  \
# 0            1  16e621b40e2a0718  16e3d0dba31c9f02 2019-11-13 00:00:00
# 1            2  16d5f62086593562  16d2ce551f3bb65a 2019-09-23 00:00:00
# 2            3  16c0626420c86643  16bfb3ebc5852120 2019-07-18 00:00:00
# 3            4  16eb93bc25e0f323  16eb93bc25e0f323 2019-11-29 00:00:00
# 4            5  1700ca8ed5948627  16fe9671f13a5e14 2020-02-03 00:00:00
# ...        ...               ...               ...                 ...
# 30082    32110  17566fd6b8213ce5  17566fd6b8213ce5 2020-10-26 22:17:26
# 30083    32111  175670b082979f82  175670b082979f82 2020-10-26 22:32:57
# 30084    32112  17567099bfd9ea26  17567099bfd9ea26 2020-10-26 22:31:20
# 30085    32113  1756706f2419d084  17546928d9c3172b 2020-10-26 22:28:29
# 30086    32114  1756706e769d9ae3  1756706e769d9ae3 2020-10-26 22:28:23
#
#         mail_hms_received                                       mail_subject  \
# ...

# %%
cqdb_prod.TablesList()
# Out:
# ['Access_level',
#  'Address',
#  'Bancos',
#  'Delivery_Check',
#  'Emissary',
#  'Emissary_Status',
#  'IP_block',
#  'Label',
#  'Monitoring',
#  'Rating',
#  'Role',
#  'Screening',
#  'Trix',
#  'Users',
#  'Users_status']

# %%
cqdb.TablesDataType('screening_table')
# Out:
#                          0               1    2    3                  4  \
# 0                  main_id         int(11)   NO  PRI               None
# 1                  mail_id     varchar(50)   NO                    None
# 2                thread_id     varchar(50)   NO                    None
# 3       mail_date_received            date   NO                    None
# 4        mail_hms_received            time   NO                    None
# 5             mail_subject  varchar(10000)   NO                    None
# 6                mail_from     varchar(60)   NO                    None
# 7                mail_body        longblob  YES                    None
# 8        mail_body_snippet   varchar(5000)  YES                    None
# 9           has_attachment   enum('0','1')   NO                    None
# 10  attachment_folder_link     varchar(50)  YES                    None
# 11                 case_id     varchar(50)  YES                    None
# ...

# %%
cqdb_prod.TablesDataType('Screening')
# Out:
#                          0               1    2    3                  4  \
# 0                  main_id         int(11)   NO  PRI               None
# 1                  mail_id     varchar(50)   NO                    None
# 2                thread_id     varchar(50)   NO                    None
# 3       mail_date_received        datetime   NO                    None
# 4        mail_hms_received        datetime   NO                    None
# 5             mail_subject  varchar(10000)   NO                    None
# 6                mail_from     varchar(60)   NO                    None
# 7                mail_body        longblob  YES                    None
# 8        mail_body_snippet   varchar(5000)  YES                    None
# 9           has_attachment         int(11)   NO                    None
# 10  attachment_folder_link     varchar(50)  YES                    None
# 11                 case_id     varchar(50)  YES                    None
# ...

# %%
df_test = pd.DataFrame(columns = ['mail_id', 'thread_id', 'mail_date_received',\
                                  'mail_hms_received', 'mail_subject', 'mail_from', 'mail_body',\
                                  'mail_body_snippet', 'has_attachment', 'attachment_folder_link', 
                                  'case_id', 'external_ref_number'])

# %%
# Out:
# datetime.datetime(2020, 7, 1, 1, 36, 17, 473834)

# %%
df_test.at[0, 'mail_id'] = 'bláblá'
df_test.at[0, 'thread_id'] = 'teste'
df_test.at[0, 'mail_date_received'] = datetime.today()
df_test.at[0, 'mail_hms_received'] = datetime.today()
df_test.at[0, 'mail_subject'] = 'teste'
df_test.at[0, 'mail_from'] = 'teste'
df_test.at[0, 'mail_body'] = 'teste'
df_test.at[0, 'mail_body_snippet'] = 'teste'
df_test.at[0, 'has_attachment'] = 0
df_test.at[0, 'attachment_folder_link'] = 'teste'
df_test.at[0, 'case_id'] = 'teste'
df_test.at[0, 'external_ref_number'] = 'teste'

# %%
df_test
# Out:
#   mail_id thread_id          mail_date_received           mail_hms_received  \
# 0  bláblá     teste  2020-07-01 03:12:43.342260  2020-07-01 03:12:43.342331
#
#   mail_subject mail_from mail_body mail_body_snippet has_attachment  \
# 0        teste     teste     teste             teste              0
#
#   attachment_folder_link case_id external_ref_number
# 0                  teste   teste               teste

# %%
from sqlalchemy import create_engine
## create sqlalchemy engine
engine = create_engine("mysql://{user}:{pw}@localhost/{db}?charset=utf8mb4"
                       .format(user="root",
                               pw="quito2020",
                               db='brspcqadev'), encoding="utf8")
#logging.info('Loading MySQL database.')

## Insert whole DataFrame into MySQL
df_test.to_sql('Screening', con = engine, if_exists = 'append', index = False, chunksize = 1000)
#logging.info('Data written to MySQL database.')
engine.dispose()

# %%
data_path = os.path.join(cwd, '_collect_control')

# %%
interest_list = [item for item in os.listdir(data_path) if '.csv' in item]
interest_list
# Out:
# ['to_data.csv', 'att_data.csv', 'log.csv', 'mid_base.csv']

# %%
df = pd.read_csv(os.path.join(data_path, 'att_data.csv'), sep = '\t', encoding = 'utf-8')

# %%
df
# Out:
#                 mail_id                       doc_name  \
# 0      16e7f52e8897940d                   316:2019.pdf
# 1      16efbfe76f3c98a7        02367-2019_Redacted.pdf
# 2      16c73a4539a90832          Court Order #6429.pdf
# 3      16ea8eba4927ca92          592-2019_Redacted.pdf
# 4      16fe846f16206c67           01 2020_Redacted.pdf
# ...                 ...                            ...
# 26188  172c5341982c58f3  0041479-74.2019.8.19.0204.pdf
# 26189  172c566d6dbdf62a  0084905-32.2020.8.19.0001.pdf
# 26190  172c57bd972c08e2         Carta IMEI 3775615.pdf
# 26191  172c58f3a4e63932         Carta IMEI 3782932.pdf
# 26192  172c596e40652f46                    77-2020.pdf
#
#                                                 doc_link
# 0      /home/dev/sigo/_attachments/16e7f52e8897940d/3...
# 1      /home/dev/sigo/_attachments/16efbfe76f3c98a7/0...
# 2      /home/dev/sigo/_attachments/16c73a4539a90832/C...
# 3      /home/dev/sigo/_attachments/16ea8eba4927ca92/5...
# ...

# %%
df_screening = cqdb_prod.GetTable('Screening', 'main_id, mail_id')
df_att_final = df_screening.merge(df, on = 'mail_id', how = 'right').dropna()
df_att_final['main_id'] = df_att_final['main_id'].astype(int)
df_att_final = df_att_final.drop('mail_id', axis = 1)
df_att_final
# Out:
#       main_id                                doc_name  \
# 0           1                         3085942 (2).pdf
# 1           2                             2750653.pdf
# 2           4              007900-8-2019_Redacted.pdf
# 3           5                             3431332.pdf
# 4           7                             2741646.pdf
# ...       ...                                     ...
# 1505      999  0056550-98.2019.8.26.0050_Redacted.pdf
# 1506     1000                   Court Order #7145.pdf
# 1507     1000                   Court Order #7145.pdf
# 1508     1002                            316:2019.pdf
# 1509     1002                            316:2019.pdf
#
#                                                doc_link
# 0     /home/dev/sigo/_attachments/16e621b40e2a0718/3...
# 1     /home/dev/sigo/_attachments/16d5f62086593562/2...
# 2     /home/dev/sigo/_attachments/16eb93bc25e0f323/0...
# 3     /home/dev/sigo/_attachments/1700ca8ed5948627/3...
# ...

# %%
cqdb_prod.TablesDataType('Attachment')
# Out:
#                0             1    2    3                  4  \
# 0  attachment_id       int(11)   NO  PRI               None
# 1        main_id       int(11)   NO  MUL               None
# 2       doc_name  varchar(500)  YES                    None
# 3       doc_link  varchar(500)  YES                    None
# 4   date_created     timestamp   NO       CURRENT_TIMESTAMP
# 5   date_updated     timestamp   NO       CURRENT_TIMESTAMP
#
#                              5
# 0               auto_increment
# 1
# 2
# 3
# 4  on update CURRENT_TIMESTAMP
# 5  on update CURRENT_TIMESTAMP

# %%
#df_att_final['doc_link'] = df_att_final['doc_link'].str.encode('utf-8') 
#df_att_final['doc_name'] = df_att_final['doc_name'].str.encode('utf-8').astype(str)

# %%
for k in range(0, len(df_att_final)):
    df_row = df_att_final.loc[k, :].to_frame().T
    result = cqdb_prod.InsertDB(df_row, 'Attachment', key_column = 'doc_link', return_table = False)
    print(k)
    print(' ')
    print(' ')
# Out:
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 0
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 1
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 2
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 3
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 4
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 5
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 6
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 7
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 8
#
#
# Original length: 1
# DB length: 1876
# Final length: 0
# No data to be written in the db.
# 9
#
#
# ...

# %%
cqdb_prod.GetTable('Attachment')
# Out:
#        attachment_id  main_id                                doc_name  \
# 0                  1      313               Court Order #6121 (2).pdf
# 1                  2      783                             2739214.pdf
# 2                  3      313               Court Order #6121 (2).pdf
# 3                  4      513                   Court Order #7590.pdf
# 4                  5      313               Court Order #6121 (2).pdf
# ...              ...      ...                                     ...
# 12661          13284    14351  0000082-14.2019.4.01.3100_Redacted.pdf
# 12662          13285    14352                        703_Redacted.pdf
# 12663          13286    14352                        712_Redacted.pdf
# 12664          13287    14353                         Ref+3729968.pdf
# 12665          13288    14354                   Court Order #8804.pdf
#
#                                                 doc_link        date_created  \
# ...

# %%
df_screening = cqdb_prod.GetTable('Screening')
df_screening.sort_values('mail_date_received', ascending = False)
# Out:
#        main_id           mail_id         thread_id  mail_date_received  \
# 15240    15482  1730c50c98e05d33  172e84f1fc58e356 2020-07-01 21:38:07
# 14810    15052  1730c24030bd053e  1730c24030bd053e 2020-07-01 20:49:12
# 14183    14425  1730c16ed3c6cb77  1730c16ed3c6cb77 2020-07-01 20:34:53
# 16415    16657  1730c0edb333c98c  1730c0edb333c98c 2020-07-01 20:26:06
# 16297    16539  1730c0c30c56fc59  1730c0c30c56fc59 2020-07-01 20:23:11
# ...        ...               ...               ...                 ...
# 2574      2575  16b6cb7c7e15c924  16b6cb7c7e15c924 2019-06-18 22:31:49
# 7462      7463  16b6cb6ff697c2af  16b6cb6ff697c2af 2019-06-18 22:30:58
# 10127    10228  16b6cb501fd2e09b  16b6cb501fd2e09b 2019-06-18 22:28:47
# 15566    15808  16b6cb4361be635d  16b6cb4361be635d 2019-06-18 22:27:56
# 5472      5473  16b66603ebd89f26  16b66603ebd89f26 2019-06-17 16:58:32
#
#         mail_hms_received                                       mail_subject  \
# ...

# %%
os.listdir(data_path)
# Out:
# ['pid_DataCollector.dat',
#  'to_data.csv',
#  'att_data.csv',
#  'log.csv',
#  'subset_mail_error.dat',
#  'mid_base.csv',
#  'logging_app.log']

# %%
df_mid = pd.read_csv(os.path.join(data_path, 'mid_base.csv'), sep = '\t', encoding = 'utf-8')

# %%
df_mid
# Out:
#                      id          threadId       after      before
# 0      1709e2dba8f969ad  1708d1d9ae8b8645  2018-01-01  2020-03-04
# 1      1709e261f35d80fd  1709e261f35d80fd  2018-01-01  2020-03-04
# 2      1709e1b9dd48e838  1709e1b9dd48e838  2018-01-01  2020-03-04
# 3      1709e1669f34cff4  170692f5e2c5f209  2018-01-01  2020-03-04
# 4      1709df0f2361e2b3  1709df0f2361e2b3  2018-01-01  2020-03-04
# ...                 ...               ...         ...         ...
# 19724  17307c059fb51e77  17307c059fb51e77  2020-07-01  2020-07-02
# 19725  17307bea25e1d939  17307bea25e1d939  2020-07-01  2020-07-02
# 19726  17308e469942ded6  17306ea0a3aa2a34  2020-07-01  2020-07-02
# 19727  1730a322184c45b9  1730a322184c45b9  2020-07-01  2020-07-02
# 19728  1730a62c5baef99f  17300b01f44f8ad4  2020-07-01  2020-07-02
#
# [19729 rows x 4 columns]

# %%
df_mid[df_mid['after'] == '2020-07-01']
# Out:
#                      id          threadId       after      before
# 19717  1730838f9d0a628b  1730365157aa6ad5  2020-07-01  2020-07-02
# 19718  173082f3ea9a8667  17281172f0ef8472  2020-07-01  2020-07-02
# 19719  1730828e53778db3  1730828e53778db3  2020-07-01  2020-07-02
# 19720  1730823982df7132  172f27e4f3f573f9  2020-07-01  2020-07-02
# 19721  173081f8682f389c  173081f8682f389c  2020-07-01  2020-07-02
# 19722  17307d345a6c0338  17307d345a6c0338  2020-07-01  2020-07-02
# 19723  17307c0a9e28e0bb  17307c0a9e28e0bb  2020-07-01  2020-07-02
# 19724  17307c059fb51e77  17307c059fb51e77  2020-07-01  2020-07-02
# 19725  17307bea25e1d939  17307bea25e1d939  2020-07-01  2020-07-02
# 19726  17308e469942ded6  17306ea0a3aa2a34  2020-07-01  2020-07-02
# 19727  1730a322184c45b9  1730a322184c45b9  2020-07-01  2020-07-02
# 19728  1730a62c5baef99f  17300b01f44f8ad4  2020-07-01  2020-07-02

# %%
## test DB ~ 20k mails (collect stopped 2020-07-01)
#cqdb.GetTable('screening_table')
