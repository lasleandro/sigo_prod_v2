# %%
from PIL import Image
import pytesseract
from pdf2image import convert_from_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-37bedfd9d4a3> in <module>
#       1 from PIL import Image
# ----> 2 import pytesseract
#       3 from pdf2image import convert_from_path
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
pages = convert_from_path('fluxo.pdf', 500)

# %%
type(pages)
# Out:
# list

# %%
len(pages)
# Out:
# 9

# %%
pages[6]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4132x5848 at 0x7F4102D7B160>

# %%
print(pytesseract.image_to_string(pages[6]))
# Out:
# CARINA QUITO
#
# ADVOGADOS
#
# Segue abaixo 0 modelo atualmente adotado:
#
# Last Name: 1a Vara Criminal da Comarca de Tramandal’ - RS
# Country: BR
#
# External Reference Number: 0013859—72.2018.8.21.0073
# Date the Court Order was Issued: 2018/12/05
#
# Date Received: 2018/12/27
#
# Due Date: 2019/01/02
#
# Targets: lexxx -- Gmail, leaxxx — Gmail, phone numbers
#
# Info: Ofl’cio n. 2332/2018
#
# Trix #4633
#
# Related to: [1-2203000025033]
#
# LP indicates email for delivery of response:
#
# Yes (share data directly with LE):
#
# Via email: roubo-banco@pc.rs.gov.br
# Counsel needs to review letter: yes
#
# LEGAL OPINION:
#
# 1/ Background: n/a —
# —
#
# 2/ Legal risks: n/a —
# 3/ Legal issue: n/a —
#
# 4/ Additional information: n/a —
# —
#
# Letter should be addressed to: Exmo. Senhor Delegado de Policia Civil da 18‘ Delegacia de
#
# Policia de Repressao a Roubos em Porto Alegre/RS - Dr. Joao Paulo Abreu
#
# Silo: International Criminal
#
#
#
# +55112124-3550 l+55112124-3551
# ...

# %%
pages[1]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=4132x5848 at 0x7F4134287780>

# %%
pytesseract.image_to_string(Image.open('test_order.pdf'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-957e50a73471> in <module>()
# ----> 1 pytesseract.image_to_string(Image.open('test_order.pdf'))
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2588         fp.close()
#    2589     raise IOError("cannot identify image file %r"
# -> 2590                   % (filename if filename else fp))
#    2591
#    2592 #
#
# OSError: cannot identify image file 'test_order.pdf'
